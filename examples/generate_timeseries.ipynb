# %%
import sys
sys.path.append('/Users/wastechs/Documents/git-repos/energy-efficiency')
from lib import generate_aggregate_timeseries

# %%
generate_aggregate_timeseries.run_timeseries()
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost/postgres)
# Creating 1T time aggregation materialized view for gesamtmessung
# Creating 5T time aggregation materialized view for gesamtmessung
# Creating 10T time aggregation materialized view for gesamtmessung
# Creating 15T time aggregation materialized view for gesamtmessung
# Creating 30T time aggregation materialized view for gesamtmessung
# Creating 1H time aggregation materialized view for gesamtmessung
# Time aggregation materialized view for gesamtmessung completed
# Creating 1T time aggregation materialized view for uv_eg
# Creating 5T time aggregation materialized view for uv_eg
# Creating 10T time aggregation materialized view for uv_eg
# Creating 15T time aggregation materialized view for uv_eg
# Creating 30T time aggregation materialized view for uv_eg
# Creating 1H time aggregation materialized view for uv_eg
# Time aggregation materialized view for uv_eg completed
# Creating 1T time aggregation materialized view for r707lv_f4032
# Creating 5T time aggregation materialized view for r707lv_f4032
# Creating 10T time aggregation materialized view for r707lv_f4032
# Creating 15T time aggregation materialized view for r707lv_f4032
# Creating 30T time aggregation materialized view for r707lv_f4032
# Creating 1H time aggregation materialized view for r707lv_f4032
# Time aggregation materialized view for r707lv_f4032 completed
# Creating 1T time aggregation materialized view for vk_2_eg
# Creating 5T time aggregation materialized view for vk_2_eg
# Creating 10T time aggregation materialized view for vk_2_eg
# Creating 15T time aggregation materialized view for vk_2_eg
# Creating 30T time aggregation materialized view for vk_2_eg
# Creating 1H time aggregation materialized view for vk_2_eg
# Time aggregation materialized view for vk_2_eg completed
# Creating 1T time aggregation materialized view for stahl_folder
# Creating 5T time aggregation materialized view for stahl_folder
# Creating 10T time aggregation materialized view for stahl_folder
# Creating 15T time aggregation materialized view for stahl_folder
# Creating 30T time aggregation materialized view for stahl_folder
# Creating 1H time aggregation materialized view for stahl_folder
# Time aggregation materialized view for stahl_folder completed
# Creating 1T time aggregation materialized view for og_3
# Creating 5T time aggregation materialized view for og_3
# Creating 10T time aggregation materialized view for og_3
# Creating 15T time aggregation materialized view for og_3
# Creating 30T time aggregation materialized view for og_3
# Creating 1H time aggregation materialized view for og_3
# Time aggregation materialized view for og_3 completed
# Creating 1T time aggregation materialized view for eg
# Creating 5T time aggregation materialized view for eg
# Creating 10T time aggregation materialized view for eg
# Creating 15T time aggregation materialized view for eg
# Creating 30T time aggregation materialized view for eg
# Creating 1H time aggregation materialized view for eg
# Time aggregation materialized view for eg completed
# Creating 1T time aggregation materialized view for entsorgung
# Creating 5T time aggregation materialized view for entsorgung
# Creating 10T time aggregation materialized view for entsorgung
# Creating 15T time aggregation materialized view for entsorgung
# Creating 30T time aggregation materialized view for entsorgung
# Creating 1H time aggregation materialized view for entsorgung
# Time aggregation materialized view for entsorgung completed
# Creating 1T time aggregation materialized view for og
# Creating 5T time aggregation materialized view for og
# Creating 10T time aggregation materialized view for og
# Creating 15T time aggregation materialized view for og
# Creating 30T time aggregation materialized view for og
# Creating 1H time aggregation materialized view for og
# Time aggregation materialized view for og completed
# Creating 1T time aggregation materialized view for uv_sigma_line_eg
# Creating 5T time aggregation materialized view for uv_sigma_line_eg
# Creating 10T time aggregation materialized view for uv_sigma_line_eg
# Creating 15T time aggregation materialized view for uv_sigma_line_eg
# Creating 30T time aggregation materialized view for uv_sigma_line_eg
# Creating 1H time aggregation materialized view for uv_sigma_line_eg
# Time aggregation materialized view for uv_sigma_line_eg completed
# Creating 1T time aggregation materialized view for r707lv_trockner
# Creating 5T time aggregation materialized view for r707lv_trockner
# Creating 10T time aggregation materialized view for r707lv_trockner
# Creating 15T time aggregation materialized view for r707lv_trockner
# Creating 30T time aggregation materialized view for r707lv_trockner
# Creating 1H time aggregation materialized view for r707lv_trockner
# Time aggregation materialized view for r707lv_trockner completed
# Creating 1T time aggregation materialized view for r707lv_vari_air
# Creating 5T time aggregation materialized view for r707lv_vari_air
# Creating 10T time aggregation materialized view for r707lv_vari_air
# Creating 15T time aggregation materialized view for r707lv_vari_air
# Creating 30T time aggregation materialized view for r707lv_vari_air
# Creating 1H time aggregation materialized view for r707lv_vari_air
# Time aggregation materialized view for r707lv_vari_air completed
# Creating 1T time aggregation materialized view for xl106_druckmaschine
# Creating 5T time aggregation materialized view for xl106_druckmaschine
# Creating 10T time aggregation materialized view for xl106_druckmaschine
# Creating 15T time aggregation materialized view for xl106_druckmaschine
# Creating 30T time aggregation materialized view for xl106_druckmaschine
# Creating 1H time aggregation materialized view for xl106_druckmaschine
# Time aggregation materialized view for xl106_druckmaschine completed
# Creating 1T time aggregation materialized view for xl106_uv_scan
# Creating 5T time aggregation materialized view for xl106_uv_scan
# Creating 10T time aggregation materialized view for xl106_uv_scan
# Creating 15T time aggregation materialized view for xl106_uv_scan
# Creating 30T time aggregation materialized view for xl106_uv_scan
# Creating 1H time aggregation materialized view for xl106_uv_scan
# Time aggregation materialized view for xl106_uv_scan completed
# Creating 1T time aggregation materialized view for hauptluftung
# Creating 5T time aggregation materialized view for hauptluftung
# Creating 10T time aggregation materialized view for hauptluftung
# Creating 15T time aggregation materialized view for hauptluftung
# Creating 30T time aggregation materialized view for hauptluftung
# Creating 1H time aggregation materialized view for hauptluftung
# Time aggregation materialized view for hauptluftung completed
# Creating 1T time aggregation materialized view for vk_1_ug
# Creating 5T time aggregation materialized view for vk_1_ug
# Creating 10T time aggregation materialized view for vk_1_ug
# Creating 15T time aggregation materialized view for vk_1_ug
# Creating 30T time aggregation materialized view for vk_1_ug
# Creating 1H time aggregation materialized view for vk_1_ug
# Time aggregation materialized view for vk_1_ug completed
# Creating 1T time aggregation materialized view for r707lv_f4034
# Creating 5T time aggregation materialized view for r707lv_f4034
# Creating 10T time aggregation materialized view for r707lv_f4034
# Creating 15T time aggregation materialized view for r707lv_f4034
# Creating 30T time aggregation materialized view for r707lv_f4034
# Creating 1H time aggregation materialized view for r707lv_f4034
# Time aggregation materialized view for r707lv_f4034 completed
# Creating 1T time aggregation materialized view for og_2
# Creating 5T time aggregation materialized view for og_2
# Creating 10T time aggregation materialized view for og_2
# Creating 15T time aggregation materialized view for og_2
# Creating 30T time aggregation materialized view for og_2
# Creating 1H time aggregation materialized view for og_2
# Time aggregation materialized view for og_2 completed
# Creating 1T time aggregation materialized view for not_in_list
# Creating 5T time aggregation materialized view for not_in_list
# Creating 10T time aggregation materialized view for not_in_list
# Creating 15T time aggregation materialized view for not_in_list
# Creating 30T time aggregation materialized view for not_in_list
# Creating 1H time aggregation materialized view for not_in_list
# Time aggregation materialized view for not_in_list completed
