# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from load_profile import load_plotter

# %%
machine1 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe33f53923d596335e69d41.csv')
machine2 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe340b3923d596335e69d47.csv')
machine3 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe340cb923d596335e69d48.csv')
machine4 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe340e3923d596335e69d49.csv')
machine5 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe340fc923d596335e69d4a.csv')

# %%
load_plotter(machine1, True).plot('P', 3, '30T')

# %%
load_plotter(machine2, True).plot('P', 3, '30T')

# %%
load_plotter(machine3, True).plot('P', 3, '30T')

# %%
load_plotter(machine4, True).plot('P', 3, '30T')

# %%
load_plotter(machine5, True).plot('P', 3, '30T') ## This is interesting - fractional values and negative?
