# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from load_profile import load_plotter

# %%
machine1 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe33f53923d596335e69d41.csv')
machine2 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe3400d923d596335e69d42.csv')
machine3 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe34044923d596335e69d43.csv')
machine4 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe34060923d596335e69d44.csv')
machine5 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe34098923d596335e69d46.csv')
machine6 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe340b3923d596335e69d47.csv')
machine7 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe340cb923d596335e69d48.csv')
machine8 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe340e3923d596335e69d49.csv')
machine9 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe340fc923d596335e69d4a.csv')
machine10 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe34116923d596335e69d4b.csv')
machine11 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe3412c923d596335e69d4c.csv')
machine12 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe34145923d596335e69d4d.csv')
machine13 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe3415e923d596335e69d4e.csv')
machine14 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe3417a923d596335e69d4f.csv')
machine15 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe34191923d596335e69d50.csv')
machine16 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe341bd923d596335e69d51.csv')
machine17 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe341d4923d596335e69d52.csv')
machine18 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/5fe341ee923d596335e69d53.csv')
machine19 = pd.read_csv('/Users/wastechs/Documents/data/clemap/cat/6017e77a42d6f4614409d192.csv')

# %%
load_plotter(machine1, True).plot('P', 3, '15T')

# %%
load_plotter(machine2, True).plot('P', 3, '30T')

# %%
load_plotter(machine3, True).plot('P', 3, '30T')

# %%
load_plotter(machine4, True).plot('P', 3, '30T')

# %%
load_plotter(machine5, True).plot('P', 3, '30T') ## This is interesting - fractional values and negative?

# %%
load_plotter(machine6, True).plot('P', 3, '30T')

# %%
load_plotter(machine7, True).plot('P', 3, '30T')

# %%
load_plotter(machine8, True).plot('P', 3, '30T')

# %%
load_plotter(machine9, True).plot('P', 3, '30T')

# %%
load_plotter(machine10, True).plot('P', 3, '30T')

# %%
load_plotter(machine11, True).plot('P', 3, '30T')

# %%
load_plotter(machine12, True).plot('P', 3, '30T')

# %%
load_plotter(machine13, True).plot('P', 3, '30T')

# %%
load_plotter(machine14, True).plot('P', 3, '30T')

# %%
load_plotter(machine15, True).plot('P', 3, '30T')

# %%
load_plotter(machine16, True).plot('P', 3, '30T')

# %%
load_plotter(machine17, True).plot('P', 3, '30T')

# %%
load_plotter(machine18, True).plot('P', 3, '30T')

# %%
load_plotter(machine19, True).plot('P', 3, '30T')
