# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import numpy as np
sys.path.append('/Users/wastechs/Documents/git-repos/energy-efficiency')
from lib.util.helper import weekday_time_series
import seaborn as sns
import plotly.express as px
from statsmodels.graphics.tsaplots import plot_acf

# %%
df = weekday_time_series(sensor_id='r707lv_f4032_10T')

# %%
px.line(
    x=df.index, y=df.p, 
    title='R707LV',
    labels={
        'x': 'Time',
        'y': 'Watts'
    })

# %%
time_int_range = np.arange(0, df.shape[0]*10, 10)
df['t'] = time_int_range
df['t_scaled'] = (df['t'] - df['t'].min()) / (df['t'].max() - df['t'].min())

# %%
fig, ax = plt.subplots(figsize=(14, 6))
plot_acf(df.kw.values.squeeze(), lags=200, ax=ax)

# %%
df['t_scaled'].iloc[25], df['t_scaled'].iloc[30]
# Out:
# (0.10460251046025104, 0.12552301255230125)

# %%
df['t_scaled'].iloc[47], df['t_scaled'].iloc[53]
# Out:
# (0.19665271966527198, 0.2217573221757322)

# %%
plt.figure(figsize=(12, 6))
plt.hist(x=df_1T.p, bins=30)
plt.show()
