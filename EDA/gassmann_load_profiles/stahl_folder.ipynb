# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/Users/wastechs/Documents/git-repos/energy-efficiency')
from lib.util.helper import weekday_time_series
import seaborn as sns
import plotly.express as px
from statsmodels.graphics.tsaplots import plot_acf

# %%
df = weekday_time_series(sensor_id='stahl_folder_10T')

# %%
px.line(
    x=df.index, y=df.kw, 
    title='Stahl Folder',
    labels={
        'x': 'Time',
        'y': 'kW'
    })

# %%
time_int_range = np.arange(0, df.shape[0]*30, 30)
df['t'] = time_int_range
df['t_scaled'] = (df['t'] - df['t'].min()) / (df['t'].max() - df['t'].min())

# %%
fig, ax = plt.subplots(figsize=(16, 6))
plot_acf(df.kw.values.squeeze(), lags=150, ax=ax)

# %%
df['t_scaled'].iloc[0], df['t_scaled'].iloc[140]
# Out:
# (0.0, 0.19471488178025034)

# %%
plt.figure(figsize=(12, 6))
plt.hist(x=df.kw, bins=30)
plt.show()
