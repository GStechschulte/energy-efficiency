# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys
sys.path.append('/Users/wastechs/Documents/git-repos/energy-efficiency')
from lib.util.helper import weekday_time_series
import seaborn as sns
import plotly.express as px
from statsmodels.graphics.tsaplots import plot_acf

# %%
df = weekday_time_series(sensor_id='r707lv_f4034_10T')

# %%
px.line(
    x=df.index, y=df.kw, 
    title='Puderabsauger: Subsystem = R707LV',
    labels={
        'x': 'Time',
        'y': 'kW'
    },
    markers=False)

# %%
#df = df[df.index.day >= 13]

# %%
time_int_range = np.arange(0, df.shape[0]*30, 30)
df['t'] = time_int_range
df['t_scaled'] = (df['t'] - df['t'].min()) / (df['t'].max() - df['t'].min())

# %%
px.line(
    x=df['t_scaled'], y=df.kw, 
    title='Entsorgung',
    labels={
        'x': 'Time',
        'y': 'kW'
    })

# %%
fig, ax = plt.subplots(figsize=(15, 6))
plot_acf(df.kw.values.squeeze(), lags=200, ax=ax)

# %%
df['t_scaled'].iloc[95], df['t_scaled'].iloc[100]
# Out:
# (0.13212795549374132, 0.13908205841446453)
