# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/Users/wastechs/Documents/git-repos/energy-efficiency')
from lib.util.helper import query_table
import seaborn as sns

# %%
df_hr = query_table(table='g_5fe34098923d596335e69d46_1H')
df_1T = query_table(table='g_5fe34098923d596335e69d46_1T')
df_5T = query_table(table='g_5fe34098923d596335e69d46_5T')

# %%
plt.figure(figsize=(20, 8))
plt.plot(df_hr.index, df_hr.kw)

# %%
plt.figure(figsize=(20, 8))
plt.plot(df_1T.index, df_1T.kw)

# %%
plt.figure(figsize=(20, 8))
plt.plot(df_5T.index, df_5T.kw)

# %%
plt.figure(figsize=(12, 6))
plt.hist(x=df_1T.kw, bins=30)
plt.show()
