# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('/Users/wastechs/Documents/git-repos/energy-efficiency')
from lib.util.helper import query_table
import seaborn as sns
import plotly.express as px

# %%
df = query_table(table='screen_printer_10T')

# %%
plt.figure(figsize=(20, 6))
plt.plot(df.index, df.kw)
plt.show()

# %%
range = df['2017-12-05 00:00:00': '2017-12-09 23:55:00']

plt.figure(figsize=(20, 6))
plt.plot(range.index, range.kw)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.hist(x=df.kw, bins=30)
plt.show()
