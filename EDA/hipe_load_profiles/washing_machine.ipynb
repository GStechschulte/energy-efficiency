# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import numpy as np
sys.path.append('/Users/wastechs/Documents/git-repos/energy-efficiency')
from lib.util.helper import query_table
from lib.visualizer import hourly_profile_heatmap
import seaborn as sns
import plotly.express as px
from statsmodels.graphics.tsaplots import plot_acf

# %%
df = query_table(table='washing_machine_1T')

# %%
df.shape
# Out:
# (132480, 2)

# %%
plt.figure(figsize=(16, 6))
plt.plot(df.index, df.kw)
plt.show()

# %%
def plot_week(df, week):
    week_sub = df[df.index.isocalendar().week == week]
    return px.line(x=week_sub.index, y=week_sub.kw)

# %%
plot_week(df, 42)

# %%
hourly_profile_heatmap(machine='washing_machine_1T')

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plot_acf(df.kw.values.squeeze(), lags=100, ax=ax)
# Out:
# /Users/wastechs/opt/anaconda3/envs/thesis/lib/python3.8/site-packages/matplotlib/axes/_base.py:2146: UserWarning:
#
# ...
